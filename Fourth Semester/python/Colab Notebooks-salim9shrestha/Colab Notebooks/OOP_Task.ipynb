# %%
class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()
  def create_pin(self):
    -------
  def change_pin(self):
    -------
  def check_balance(self):
    -------
  def withdraw(self):
    -------

# %% [markdown]
# Make a Logic of above class method
#
# Create pin()
# Change pin()
# check balance()
# withdraw()
#
# Also make above things working as a application

# %% [markdown]
# Write your understanding about self in your own language with example
