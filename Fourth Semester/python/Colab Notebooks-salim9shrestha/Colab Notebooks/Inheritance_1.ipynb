# %%
class register:
  def __init__(self, username, password):
    self.username = username
    self.password = password

  def login(self):
    print("you are login in")

class instructor(register):
  def check(self):
    print("checked into the course")

class student(register):
  def enroll(self):
    print("enroll into the course")

# %%
i = instructor("salim", "securepass123")
s = student("santosh", "password456")

print(s.username)
print(i.username)
s.login()
i.login()
i.check()
# Out:
# santosh
# salim
# you are login in
# you are login in
# checked into the course
