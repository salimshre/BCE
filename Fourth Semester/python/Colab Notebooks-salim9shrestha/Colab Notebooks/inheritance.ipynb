# %%
class user:
  def __init__(self):
    self.name = "santosh"
    self.gender = "female"

  def login(self):
   print("login")

# %%
class student(user):
  def enroll(self):
    print("enroll into the course")

u = user()
s = student()

print(s.name)
s.login()
s.enroll()
# Out:
# santosh
# login
# enroll into the course
