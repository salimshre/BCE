# %%
x = 7
is_prime = True

for i in range(2, x):
    if x % i == 0:
        is_prime = False
        break

if is_prime == True:
    print("Prime")
else:
    print("Not Prime")
# Out:
# Prime

# %%
for i in range(2,7):
  print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
